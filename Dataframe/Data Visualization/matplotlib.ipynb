# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\internship\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\anaconda3\envs\internship\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\internship\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame

# %%
data = {'names':['steve', 'john', 'richard', 'sarah', 'randy', 'micheal', 'julie'],
        'age':[20, 22, 20, 21, 24, 23, 22],
        'gender':['Male', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female'],
        'rank':[2, 1, 4, 5, 3, 7, 6]}

df=DataFrame(data)
df
# Out:
#      names  age  gender  rank
# 0    steve   20    Male     2
# 1     john   22    Male     1
# 2  richard   20    Male     4
# 3    sarah   21  Female     5
# 4    randy   24    Male     3
# 5  micheal   23    Male     7
# 6    julie   22  Female     6

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ### Bar matplotlib

# %%
plt.bar(df['names'], df['age'])
plt.xlabel('Names')
plt.ylabel('Age')
plt.title("Comparing Ages")
plt.show()

# %% [markdown]
# ## Bar plot using Seaborn

# %%
plot=sns.barplot(data=df, x="names", y='age')
plot.set_title("Compared Ages")
plt.show()

# %% [markdown]
# ## Line plot matplotlib

# %%
plt.plot(df['names'], df['age'])
plt.xlabel("Names")
plt.ylabel("Age")
plt.title("Compared Ages")
plt.show()

# %% [markdown]
# ## Line plot using seaborn

# %%
plot=sns.lineplot(data=df, x="names", y="age")
plot.set_title("Compared Age")
plt.show()

# %% [markdown]
# ## Pie chart matplotlib

# %%
plt.pie(df['age'],labels=df['names'])
plt.title("Age Comparison")
plt.show()

# %%
colors=sns.color_palette('pastel')
plt.pie(df['age'], labels=df['names'], colors=colors)
plt.show()
